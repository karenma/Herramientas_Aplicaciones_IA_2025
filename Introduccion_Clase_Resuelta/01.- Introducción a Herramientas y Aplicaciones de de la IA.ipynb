# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1>Introducción a Herramientas y Aplicaciones de la Inteligencia Artificial</h1>
# </div>
#
#
# <div style="background-color:#f9f9f9; border-left:4px solid #000047; padding:10px; margin-top:10px;">
# <b>Objetivo:</b> Conocer el panorama general de la IA, sus aplicaciones y las herramientas computacionales clave para el desarrollo de proyectos modernos.
# </div>

# %% [markdown]
# # ¿Qué es la Inteligencia Artificial?
#
# **La inteligencia artificial (IA)** está transformando industrias y la vida cotidiana. Su capacidad para procesar grandes volúmenes de datos y aprender de ellos ha impulsado avances en medicina, ingeniería, educación, comercio y más.
#
# El desarrollo de IA requiere conocimientos en algoritmos, matemáticas y lenguajes de programación especializados. Elegir la herramienta adecuada es fundamental para el éxito de cualquier proyecto.
#
# <div style="background-color:#e6ffe6; border-left:4px solid #008000; padding:10px;">
# <b>Dato:</b> Python es el lenguaje más popular para IA y Machine Learning, gracias a su sintaxis sencilla y su enorme ecosistema de librerías.
# </div>

# %% [markdown]
# ---
# ## 🌍 Aplicaciones de la IA
#
# La IA tiene un impacto en múltiples áreas, tales como:
#
# - Motores de búsqueda inteligentes
# - Diagnóstico médico asistido
# - Detección de fraude financiero
# - Análisis de mercados bursátiles
# - Clasificación de secuencias de ADN
# - Reconocimiento de voz y texto
# - Juegos y robótica
# - Automatización industrial
#
# <div style="background-color:#f9f9f9; border-left:4px solid #000047; padding:10px;">
# Para abordar estos temas, es esencial distinguir los distintos tipos de problemas de Machine Learning.
# </div>

# %% [markdown]
# ### Tipos de Aprendizaje en Machine Learning
#
# **Aprendizaje supervisado:**
#
# El algoritmo aprende a partir de datos etiquetados (con la respuesta correcta). Tras el entrenamiento, puede predecir resultados para nuevos datos. Ejemplo: clasificación de correos como spam/no spam.
#
# **Aprendizaje no supervisado:**
#
# El algoritmo explora datos sin etiquetas, buscando patrones y agrupaciones. Ejemplo: segmentación de clientes en marketing.
#
# **Aprendizaje por refuerzo:**
#
# El algoritmo aprende mediante ensayo y error, recibiendo recompensas o penalizaciones según sus acciones. Ejemplo: entrenamiento de agentes para jugar videojuegos o controlar robots.

# %% [markdown]
# ---
# ## 🛠️ Herramientas y Librerías de Python para IA y Machine Learning
#
# Python destaca por su comunidad activa y la gran variedad de librerías especializadas. Algunas de las más importantes son:
#
# ### <img src="https://iasolver.es/wp-content/uploads/2021/06/scipy-logo.jpg" width="80"/> SciPy
#
# Módulos para tareas científicas y analíticas: álgebra lineal, integración, optimización, procesamiento de señales e imágenes. Depende de Numpy para sus estructuras de datos.
#
# ### <img src="https://iasolver.es/wp-content/uploads/2021/06/scikit-learn-logo.jpg" width="80"/> Scikit-Learn
#
# La librería principal para Machine Learning en Python. Incluye algoritmos de clasificación, regresión, agrupamiento, reducción de dimensionalidad y herramientas para evaluación y validación.
#
# ### <img src="https://www.statsmodels.org/stable/_images/statsmodels-logo-v2-horizontal.svg" width="120"/> Statsmodels
#
# Enfocada en modelos estadísticos y análisis predictivo/exploratorio. Ideal para ajustar modelos lineales y realizar pruebas estadísticas.
#
# ### <img src="https://www.pymc.io/_static/PyMC.jpg" width="80"/> PyMC
#
# Implementa modelos estadísticos bayesianos y métodos MCMC. Útil para análisis bayesiano y diagnóstico de modelos.
#
# ### <img src="https://miro.medium.com/v2/resize:fit:720/format:webp/1*-dNH8WI8Oy3etClaRvRCgw.png" width="80"/> NLTK
#
# Líder en procesamiento de lenguaje natural (NLP). Proporciona herramientas para clasificación, tokenización, análisis sintáctico y semántico.
#
# ### <img src="https://iasolver.es/wp-content/uploads/2021/06/tensorflow-logo.jpg" width="80"/> TensorFlow
#
# Librería open source de Google para Deep Learning. Permite construir y entrenar modelos de ML de forma sencilla, con APIs como Keras para prototipado rápido.
#
# ### Otras librerías populares en IA con Python
#
# - **Keras**: API de alto nivel para redes neuronales, integrada con TensorFlow.
# - **PyTorch**: Framework flexible y potente para Deep Learning, desarrollado por Facebook.
# - **OpenCV**: Librería para procesamiento de imágenes y visión computacional.
# - **spaCy**: Procesamiento avanzado de lenguaje natural (NLP).
# - **Transformers (Hugging Face)**: Modelos de NLP de última generación (BERT, GPT, etc.).
# - **XGBoost**: Algoritmo eficiente para problemas de clasificación y regresión.
# - **LightGBM**: Algoritmo de boosting rápido y eficiente para grandes volúmenes de datos.
# - **CatBoost**: Algoritmo de boosting optimizado para variables categóricas.
# - **Theano**: Framework para computación matemática y redes neuronales (menos usado actualmente).
# - **Caffe**: Framework para Deep Learning, especialmente en visión computacional.
# - **FastAI**: Librería de alto nivel para Deep Learning basada en PyTorch.
# - **Gensim**: Modelado de tópicos y procesamiento de texto.
# - **NetworkX**: Análisis y visualización de grafos y redes complejas.
# - **Dask**: Computación paralela y escalable para grandes volúmenes de datos.

# %% [markdown]
# ---
# ## 🚦 ¿Cómo utilizar las herramientas de IA?
#
# Para programar y aplicar IA, es necesario dominar lenguajes como Python y conocer las librerías especializadas. El aprendizaje automático permite a las máquinas mejorar su rendimiento con el tiempo, optimizando procesos y generando valor en productos y servicios.

# %% [markdown]
# ---
# ## 🏗️ Pasos para construir un modelo de Machine Learning
#
# 1. **Recolectar los datos:** Desde APIs, bases de datos, sensores o fuentes públicas.
# 2. **Preprocesar los datos:** Limpiar, transformar y preparar los datos para el modelo.
# 3. **Explorar los datos:** Analizar estadísticas, visualizar patrones y detectar valores atípicos.
# 4. **Entrenar el algoritmo:** Utilizar técnicas de ML para extraer información útil.
# 5. **Evaluar el algoritmo:** Medir la precisión y ajustar parámetros si es necesario.
# 6. **Utilizar el modelo:** Aplicar el modelo al problema real y monitorear su desempeño.

# %% [markdown]
# ---
# ## 🔢 Algoritmos más utilizados en Machine Learning
#
# A continuación se muestra una lista de los algoritmos más populares en Machine Learning:
#
# 1. [Regresión Lineal](https://es.wikipedia.org/wiki/Regresi%C3%B3n_lineal)
# 2. [Regresión Logística](https://es.wikipedia.org/wiki/Regresi%C3%B3n_log%C3%ADstica)
# 3. [Árboles de Decisión](https://es.wikipedia.org/wiki/%C3%81rbol_de_decisi%C3%B3n)
# 4. [Random Forest](https://es.wikipedia.org/wiki/Random_forest)
# 5. [Support Vector Machines (SVM)](https://es.wikipedia.org/wiki/M%C3%A1quinas_de_vectores_de_soporte)
# 6. [K-Nearest Neighbors (KNN)](https://es.wikipedia.org/wiki/K-vecinos_m%C3%A1s_cercanos)
# 7. [K-Means Clustering](https://es.wikipedia.org/wiki/K-means)
# 8. [Naive Bayes](https://es.wikipedia.org/wiki/Clasificador_naive_Bayes)
# 9. [Redes Neuronales Artificiales](https://es.wikipedia.org/wiki/Red_neuronal_artificial)
# 10. [Gradient Boosting Machines (GBM)](https://en.wikipedia.org/wiki/Gradient_boosting)
