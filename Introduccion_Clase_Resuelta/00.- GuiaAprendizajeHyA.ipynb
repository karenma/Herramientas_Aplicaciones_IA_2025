# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1>Herramientas y Aplicaciones de la Inteligencia Artificial</h1>
#     <h3>Guía de Aprendizaje 2025</h3>
#
# </div>

# %% [markdown]
# <div style="text-align: right;">
# <img src="https://idavinci.es/wp-content/uploads/2018/12/machinelearning.png" width="350px" style="float: right; margin: 0px 0px 15px 15px;" />
# </div>
#
# ### <span style="color:#2E9AFE">Horarios</span>
# - **Viernes:** 17:00 a 21:00 hrs
# - **Sábados:** 9:00 a 13:00 hrs
#
# **Profesor:** <span style="color:#000047"><strong>Gaddiel Desirena López</strong></span>
# **Año:** 2025
# **Email:** <span style="color:blue">gdesirena@gmail.com</span>
#
# <hr style="border:1px solid #2E9AFE;">

# %% [markdown]
# ## 👨‍🏫 Presentación del Profesor
#
# ¡Hola! Soy Gaddiel Desirena López, apasionado por la Inteligencia Artificial y su aplicación en la vida real.
#
# - Tengo experiencia como científico de datos, experiencia en todo el ciclo de vida de los datos y desarrollo de algoritmos predictivos.
#
# - Formación académica: Doctorado y Maestría en Ingeniería Eléctrica (CINVESTAV-IPN).
#
# - Actualmente trabajo como ingeniero de Algoritmos en Continental Autonomous Mobility: desarrollo de modelos matemáticos de sensores (radares) y aplicación de inteligencia artificial para clasificación y detección.
#
# - Experiencia docente en inteligencia artificial y sistemas en tiempo real.
#
#
# > _"La inteligencia artificial no reemplazará a los humanos, pero los humanos que la utilicen reemplazarán a los que no lo hagan."_

# %% [markdown]
# ## 🙋‍♂️ Presentación de los Estudiantes
#
# Por favor, comparte con el grupo:
# - Tu nombre y formación.
# - ¿Qué esperas aprender en este curso?
# - ¿Tienes experiencia previa con IA o programación?
# - Un dato curioso sobre ti.
#
# <hr>

# %% [markdown]
# ## 📜 Reglas de Convivencia y Participación
#
# 1. **Entrega de trabajos:** Todas las entregas se realizan a través de la plataforma [ALINNCO](https://digital.alinnco.mx/course/view.php?id=279) en los plazos asignados. No se aceptan trabajos fuera de la plataforma ni fuera de plazo.
# 2. **Participación activa:** Tu participación en clase es clave para el aprendizaje y puede influir en tu calificación final.
# 3. **Responsabilidad:** Revisa regularmente la plataforma para estar al tanto de avisos, materiales y fechas de entrega.
# 4. **Respeto:** Mantén siempre el respeto hacia tus compañeros y el profesor para un ambiente de trabajo óptimo.
# 5. **Comunicación:** Ante dudas o problemas, comunícate oportunamente con el profesor por los canales oficiales.

# %% [markdown]
# ## 🕑 Horario de Asesoría
#
# - **Solicita tu asesoría enviando un mensaje/correo con anticipación para coordinarnos.**
#
# <hr>

# %% [markdown]
# ## 📖 Descripción de la Asignatura
#
# Esta asignatura te brindará conocimientos y habilidades esenciales para el uso de herramientas y aplicaciones de Inteligencia Artificial (IA). Aprenderás a extraer y analizar datos de diversas fuentes, utilizar herramientas para el desarrollo de aplicaciones de IA, y aplicar modelos clásicos y avanzados, incluyendo técnicas de reducción de dimensionalidad y redes neuronales.
#
# A través de casos prácticos y aplicaciones reales, comprenderás el proceso completo: desde la obtención de datos hasta la implementación de soluciones inteligentes que generen valor en distintos ámbitos profesionales.
#
# <hr>

# %% [markdown]
# ## 7-7.30 descanso **Viernes**
# ## 11-11.30 descanso **Sábados**

# %% [markdown]
# ## 🎯 Objetivos del Curso
#
# | Objetivo General | Objetivos Específicos |
# |------------------|----------------------|
# | Aplicar conceptos, principios, teorías y modelos de IA para diseñar y desarrollar sistemas inteligentes y sus aplicaciones. | - Comprender y practicar algoritmos de Machine Learning (ML).<br>- Utilizar ML para agregar valor a sistemas de información.<br>- Conocer técnicas avanzadas de resolución de problemas de IA.<br>- Integrar modelos de IA en sistemas reales. |
#
# <hr>

# %% [markdown]
# ## 🗂️ Contenido Temático
#
# <details>
# <summary><strong>Introducción</strong></summary>
# <ul>
# <li>Guía de aprendizaje</li>
# <li>Herramientas computacionales</li>
# <li>Introducción a Herramientas y Aplicaciones de la IA</li>
# <li>Análisis Simbólico con Python</li>
# <li>Herramientas de extracción de datos de diferentes fuentes</li>
# </ul>
# </details>
#
# <details>
# <summary><strong>Módulo 1: Herramientas para Procesamiento y Análisis de Datos</strong></summary>
# <ul>
# <li>Identificación de datos y creación de librería</li>
# <li>Procesamiento y análisis exploratorio de datos</li>
# <li>Tratamiento de datos faltantes y atípicos</li>
# <li>Distribución de datos</li>
# </ul>
# </details>
#
# <details>
# <summary><strong>Módulo 2: Modelos y Algoritmos para Aplicaciones de IA</strong></summary>
# <ul>
# <li>Modelos clásicos de ML: Regresión lineal, polinomial y multinomial</li>
# <li>Árboles de decisión</li>
# <li>Reducción de dimensionalidad: PCA</li>
# <li>Máquina de vector soporte (SVM)</li>
# </ul>
# </details>
#
# <details>
# <summary><strong>Módulo 3: Modelos y Algoritmos Avanzados para IA</strong></summary>
# <ul>
# <li>Redes neuronales (Perceptrón, Multiclase)</li>
# <li>Librerías de redes neuronales</li>
# <li>Aplicaciones prácticas de redes neuronales</li>
# </ul>
# </details>
#
# <hr>

# %% [markdown]
# ## 📝 Evaluación
#
# | Actividad         | Porcentaje |
# |-------------------|:----------:|
# | Tareas            |   30%      |
# | Actividades       |   30%      |
# | Proyecto Final   |   40%      |
#
# <span style="color:#2E9AFE">La constancia y la creatividad serán clave para tu éxito.</span>
# <hr>

# %% [markdown]
# ## 📚 Bibliografía y Recursos Recomendados
#
# - **Mackay, D. J.C.** _Information Theory, Inference, and Learning Algorithms_. Cambridge University Press, 2003.
# - **Deisenroth, M. P., Faisal, A., & Ong, C. S.** _Mathematics for Machine Learning_. Cambridge University Press, 2020.
# - **Bishop, C. M.** _Pattern Recognition and Machine Learning_. Springer, 2006.
# - **Mohri, M., Rostamizadeh, A., & Talwalkar, A.** _Foundations of Machine Learning_. MIT Press, 2012.
# - **Shalev-Shwartz, S. & Ben-David, S.** _Understanding Machine Learning: From Theory to Algorithms_. Cambridge University Press, 2014.
# - [Python Official Website](https://www.python.org/)
# - [Kaggle: Learn Machine Learning](https://www.kaggle.com/learn)
# - _Python for Scientists_ by John M. Stewart
# - _Machine Learning for Time Series Forecasting with Python_
# - _Deep Learning for Time Series Forecasting: Predict the Future with MLPs, CNNs and LSTMs in Python_
#
# **Recursos adicionales:**
# - [Scikit-learn Documentation](https://scikit-learn.org/stable/)
# - [TensorFlow Tutorials](https://www.tensorflow.org/tutorials)
# - [PyTorch Tutorials](https://pytorch.org/tutorials/)
#
# <hr>
