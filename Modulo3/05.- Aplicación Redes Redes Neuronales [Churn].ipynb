# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1> Aplicación Redes Neuronales [Churn]</h1>
# </div>

# %%
import numpy as np
import pandas as pd
from HyAIA import HyAIA as hya

# %%
# importar el dataset
dataset = pd.read_csv('Data/Churn_Modelling.csv')

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Particionar el dataset en train y test

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Configuración de la Red

# %% [markdown]
# ## Configuración del entrenamiento

# %% [markdown]
# ## Visualización

# %% [markdown]
# ## Evaluar el modelo

# %% [markdown]
# <h2 style="color:#006633; margin-top:0;">Práctica: Hacer una predicción <span style='font-size:0.8em; color:#888;'>&#128200;</span></h2>
# <p style="font-size:1.08em;">
# Utiliza el modelo <b>nn_churn</b> para predecir si un cliente con las siguientes características dejaría el banco:
# </p>
# <ul style="font-size:1.05em;">
# <li><b>Geography:</b> France</li>
# <li><b>Credit Score:</b> 600</li>
# <li><b>Gender:</b> Male</li>
# <li><b>Age:</b> 40 años</li>
# <li><b>Tenure:</b> 3 años</li>
# <li><b>Balance:</b> 60,000</li>
# <li><b>Number of Products:</b> 2</li>
# <li><b>¿Tiene tarjeta de crédito?:</b> Sí</li>
# <li><b>¿Es miembro activo?:</b> Sí</li>
# <li><b>Estimated Salary:</b> $50,000</li>
# </ul>
# <div style="margin-top:12px; border-left:4px solid #006633; padding:10px 18px; border-radius:8px;">
# <b>Pregunta:</b> ¿Deberíamos decir adiós a este cliente? Justifica tu respuesta con la predicción del modelo y una breve interpretación.
# </div>
# </div>
