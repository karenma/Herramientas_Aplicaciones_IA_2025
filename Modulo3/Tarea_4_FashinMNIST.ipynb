# %% [markdown]
# <div style="background-color:#e6f2ff; padding:20px; border-radius:10px;">
# <img style="float:left; margin-right:20px;" src='Figures/alinco.png' width="120"/>
# <h1 style="color:#000047;">Tarea 4: Modelo de Predicción de FashionMNIST</h1>
# <br style="clear:both"/>
# </div>

# %% [markdown]
# <div style="border-left:6px solid #000047; background:#f5f5f5; border-radius:10px; padding:18px; margin-bottom:16px;">
# <h2 style="color:#000047; margin-top:0;">Instrucciones de la Tarea</h2>
# <ul style="font-size:1.08em;">
# <li>Utiliza el dataset <b>FashionMNIST</b> para construir un modelo de red neuronal.</li>
# <li>Realiza los cambios en los hiperparámetros que consideres oportunos para obtener un buen <b>accuracy</b>.</li>
# <li>Analiza y comenta los resultados obtenidos.</li>
# </ul>
# <div style="margin-top:12px; background:#e6f2ff; border-left:4px solid #000047; padding:10px 18px; border-radius:8px;">
# <b>Conjuntos de datos:</b>
# <ul>
# <li>Entrenamiento: <a href="https://drive.google.com/file/d/1L-53hgmTDeLqh6R2UK0BejPAC1WnZQiY/view?usp=drive_link" target="_blank">fashion_mnist_train</a></li>
# <li>Testeo: <a href="https://drive.google.com/file/d/1ZLvUinRuk5KziZZh7A5Woil1yg4TdklP/view?usp=drive_link" target="_blank">fashion_mnist_test</a></li>
# </ul>
# </div>
# <div style="margin-top:12px; background:#fffbe6; border-left:4px solid #b36b00; padding:10px 18px; border-radius:8px;">
# <b>Tip:</b> Prueba diferentes arquitecturas y funciones de activación para mejorar el desempeño.
# </div>
# </div>

# %%
import pandas as pd
import numpy as np

# %%
fashion = pd.read_csv('Data/fashion-mnist_train.csv')

# %%
fashion.shape

# %%
fashion['label']

# %%
fashion.columns

# %%
fashion.head()
